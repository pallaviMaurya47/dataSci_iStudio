# %% [markdown]
# #sets: {}
#
# set elements're unique
# unordered

# %% [markdown]
# does not follow indexing
# # we generally avoid sets in use

# %%
set_s={3,4,5,6,8,8,3}  #no repeated elements 
empty_set={}
type( empty_set) #dictionary ==no concept of empty set
# Out:
# dict

# %% [markdown]
# #mutability==>yes, can edit( adding & deleting /removing elements)
# but can't replace element like list or tuple does

# %% [markdown]
# #not have concept of nested set ...but have in list & tuple

# %%
list_1=[2,3,4]
list2=[5,3,2]
list_1 + list2
# Out:
# [2, 3, 4, 5, 3, 2]

# %%
tupl=(5,3,2,6)
tupl2=( 5,2,9,4)
tupl+tupl2
# Out:
# (5, 3, 2, 6, 5, 2, 9, 4)

# %%
set_f={3,5,3}
set_ff={9,4}
set_f + set_ff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 set_f={3,5,3}
#       2 set_ff={9,4}
# ----> 3 set_f + set_ff
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
#we can't add two sets like tuple & list so
# .union()
set_f.union(set_ff)
# Out:
# {3, 4, 5, 9}

# %%
#find common in both sets
set_f.intersection(set_ff)
# Out:
# set()
