# %%
#comple numbers
comp=complex( 2,3)
print( comp)

# %%
comp.real

# %%
comp.imag

# %%
list_l=[2,4,8]
new_l= list([3,2,5,6])
print(type( list_l))

# %%
list_l.append(5)
list_l.insert(2,30)

new_l.remove(2)
new_l.append(44)
new_l.extend([33,44,55])

# %%
new_l.pop(-2)
print(new_l)

# %%
new_l.sort()
print(new_l)
list.reverse(new_l)
print(new_l)
print(type(new_l))

# %%
cp_list=new_l.copy()
print(cp_list)

# %%
#delete existence of list
del list_l

# %%
nested_list=[2,7,3,6,['a','e','i'],6,9]
print(nested_list[-2][2])

# %%
help(nested_list)

# %% [markdown]
# #methods- dedicated for data
# used as .xyz()
# TO  manipulate things , make permanent changes
# like in list use new_l.append(4)
#
# #Built-in functions= print() for all DT
