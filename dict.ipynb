# %% [markdown]
# Dictionary:=> mutable, unoredered collection , elements in form of
#     key:value pairs that associate keys to values
#
# dict={key :val} --internally dictn are indexed i.e. arranged on basis of keys
# **aka Associative arrays or mappings or hashes.
#
# **keys of dictionaries= must be immutable type: string,number, tuple
# **list can't be used as key in dict["key-immutable"]
# References of key-value are stored in dict
#
# **operatin="lookup" ,finds value with key

# %% [markdown]
# >>>dict.keys()
# #list of keys: >>>list( dict.keys())
#
# >>>dict.values()
#
# **unique key
# **multiple keys can have same value, but keys must be unique
# #mapping- way of linking key with value

# %%
dicti={"key": 20,"key2":30}
print(dicti)

# %%
dicti["new_key"]=47

print(dicti["key"])

dicti.get("key")  #both methods same

# %%
#delete existing elements
del dicti["key2"] # or dicti.pop("key2")

"key" in dicti #T/F
"key" not in dicti

len(dicti)
dicti.clear()  #clear all elements but dict object still remains in memory

del dicti   #delete dict with object also.....

# %%
mylist=dicti.items()  #returns all items as seq ==[('key', 20), ('key2',30)]

# %%
subject={"hindi":68, "english":98}
science={"physics":78,"chemistry":79,"english":98}
subject.update(science)  #override elements & update

# %%
print(subject)
# Out:
# {'hindi': 68, 'english': 98, 'physics': 78, 'chemistry': 79}

# %% [markdown]
# #Garbage collection
