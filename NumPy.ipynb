# %%
import numpy as np

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/12.9 MB 1.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/12.9 MB 1.7 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.8/12.9 MB 1.9 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.9 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.9 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 3.1/12.9 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.9 MB 1.8 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.7/12.9 MB 1.8 MB/s eta 0:00:06
#    ------------ --------------------------- 3.9/12.9 MB 1.8 MB/s eta 0:00:06
# ...

# %%
#creation of 1D array:

arr=np.array([20,30,40,50,80])  #5 rows
print(arr)
# Out:
# [20 30 40 50 80]

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
new_2=np.array((2,3,4,55))
print(new_2)
# Out:
# [ 2  3  4 55]

# %%
new_dict=np.array( {32,2,9,50})
print(new_dict)
# Out:
# {32, 9, 2, 50}

# %%
type(new_dict)
# Out:
# numpy.ndarray

# %%
new_dict.ndim
# Out:
# 0

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (5,)

# %%
two_dim=np.array( [ [22,23],[43,8], [50,49]])
print(two_dim)
# Out:
# [[22 23]
#  [43  8]
#  [50 49]]

# %%
two_dim.shape
# Out:
# (3, 2)

# %%
two_dim.ndim
# Out:
# 2

# %% [markdown]
# What is difference between numpy array and Python list?

# %%
print(arr)
# Out:
# [20 30 40 50 80]

# %%
listl=[3,2,5,6]
listl
# Out:
# [3, 2, 5, 6]

# %%
list_1=[20,30,40]
list_2=[10,20,30]
#add

lis=[]
for i,j in zip(list_1,list_2):
    lis.append( i+j)
print(lis)
# Out:
# [30, 50, 70]

# %%
list_1+ list_2  #not addition but concatenation
# Out:
# [20, 30, 40, 10, 20, 30]

# %%
ar_1= np.array([20,30,40])
ar_2= np.array( [10,20,30])
#add
ar_1+ar_2
# Out:
# array([30, 50, 70])

# %%
ar_1*ar_2
# Out:
# array([ 200,  600, 1200])

# %% [markdown]
# List: consists of any type of data  but reshaping & resizing is not allowed as array
# array : same datatype
#
# Numpy arrays are faster as compared to that of list.
# less time & space

# %%
#indexing
ar_1[2]
# Out:
# np.int64(40)

# %%
ar_2[-1]
# Out:
# np.int64(30)

# %%
two_dim[2][3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 two_dim[2][3]
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
two_dim[1][1]    #row[1],in 1row --col:1
# Out:
# np.int64(8)

# %%
two_dim[0][1]
# Out:
# np.int64(23)

# %%
two_dim[0][2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 two_dim[0][2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
two_dim[0:1]
# Out:
# array([[22, 23]])

# %%
#Slicing
two_dim[0: ,1:]
# Out:
# array([[23],
#        [ 8],
#        [49]])

# %%
dim_2rr=np.array( [[20,30,40],[30,40,50],[60,30,70]])
print(dim_2rr)
# Out:
# [[20 30 40]
#  [30 40 50]
#  [60 30 70]]

# %%
dim_2rr[ 1: ,1:]
# Out:
# array([[40, 50],
#        [30, 70]])

# %%
dim_2rr[0:, 1:]
# Out:
# array([[30, 40],
#        [40, 50],
#        [30, 70]])

# %%
dim_2rr[0:2, 0:2]
# Out:
# array([[20, 30],
#        [30, 40]])

# %%
dim_2rr[0:3, 0:3]
# Out:
# array([[20, 30, 40],
#        [30, 40, 50],
#        [60, 30, 70]])

# %%
dim_2rr[0:2, ::2]   #jump=2
# Out:
# array([[20, 40],
#        [30, 50]])

# %%
dim_2rr[::2, :]
# Out:
# array([[20, 30, 40],
#        [60, 30, 70]])
